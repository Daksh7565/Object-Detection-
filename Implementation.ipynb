# %%
pip install -r requirements.txt
# Out:
# Collecting gitpython>=3.1.30Note: you may need to restart the kernel to use updated packages.
#
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      -------------------------------------- 207.6/207.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (3.5.2)
# Collecting numpy>=1.23.5
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
#      ---------------------------------------- 15.9/15.9 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (4.9.0.80)
# Collecting pillow>=10.3.0
#   Downloading pillow-11.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (6.0)
# Collecting requests>=2.32.2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (1.9.1)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting torch>=1.8.0
#   Downloading torch-2.5.1-cp39-cp39-win_amd64.whl (203.0 MB)
#      -------------------------------------- 203.0/203.0 MB 6.4 MB/s eta 0:00:00
# Collecting torchvision>=0.9.0
#   Downloading torchvision-0.20.1-cp39-cp39-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 9.9 MB/s eta 0:00:00
# Collecting tqdm>=4.66.3
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Collecting ultralytics>=8.2.34
#   Downloading ultralytics-8.3.59-py3-none-any.whl (906 kB)
#      ------------------------------------- 906.8/906.8 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 20)) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.0.4)
# Collecting numpy>=1.23.5
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.11.3)
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ---------------------------------------- 6.2/6.2 MB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2022.7.1)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.2.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.5)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting ultralytics-thop>=2.0.0
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2022.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.0.1)
# Installing collected packages: py-cpuinfo, tqdm, sympy, smmap, requests, pillow, numpy, torch, gitdb, ultralytics-thop, torchvision, thop, gitpython, ultralytics
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.10.1
#     Uninstalling sympy-1.10.1:
#       Successfully uninstalled sympy-1.10.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.2.0
#     Uninstalling Pillow-9.2.0:
#       Successfully uninstalled Pillow-9.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed gitdb-4.0.12 gitpython-3.1.44 numpy-1.24.4 pillow-11.1.0 py-cpuinfo-9.0.0 requests-2.32.3 smmap-5.0.2 sympy-1.13.1 thop-0.1.1.post2209072238 torch-2.5.1 torchvision-0.20.1 tqdm-4.67.1 ultralytics-8.3.59 ultralytics-thop-2.0.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.4 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.32.3 which is incompatible.

# %%
import cv2
import json
import numpy as np
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

color_mapping = {
    "person": (255, 0, 0),  
    "car": (0, 255, 0),     
    "bike": (0, 0, 255),    
    "motorbike": (0, 255, 255), 
    "truck": (255, 255, 0), 
    "bus": (255, 0, 255),   
}

def detect_objects(video_path):
    cap = cv2.VideoCapture(video_path)
    results = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        
        detections = model(frame)

        main_object = None
        sub_objects = []

        for result in detections:
            for box in result.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])  
                class_id = int(box.cls[0])  
                confidence = box.conf[0]  

                object_name = model.names[class_id]
                detected_object = {
                    "object": object_name,
                    "id": len(results) + 1,
                    "bbox": [x1, y1, x2, y2],
                    "subobject": {} 
                }

                box_color = color_mapping.get(object_name, (255, 255, 255))


                if object_name == "person":
                    main_object = detected_object
                else:
                    sub_objects.append(detected_object)

                cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
                cv2.putText(frame, f"{object_name}: {confidence:.2f}", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, box_color, 2)


        if main_object:
            main_object["subobject"] = sub_objects  
            results.append(main_object)
        cv2.imshow("frame",frame)

    cap.release()
    cv2.destroyAllWindows()

    with open('detection_results.json', 'w') as json_file:
        json.dump(results, json_file, indent=4)


detect_objects('sample_video.mp4')
# Out:
# 0: 640x384 2 persons, 2 cars, 1 truck, 350.5ms
# Speed: 64.1ms preprocess, 350.5ms inference, 40.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 1 bus, 1 truck, 223.9ms
# Speed: 5.9ms preprocess, 223.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 1 truck, 246.4ms
# Speed: 10.1ms preprocess, 246.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 1 truck, 205.1ms
# Speed: 12.6ms preprocess, 205.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 1 truck, 209.7ms
# Speed: 5.0ms preprocess, 209.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 1 truck, 193.2ms
# Speed: 9.8ms preprocess, 193.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 1 bus, 1 truck, 227.2ms
# Speed: 4.5ms preprocess, 227.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 1 bus,
3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 184.9ms
# Speed: 6.8ms preprocess, 184.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 1 bus, 226.0ms
# Speed: 9.5ms preprocess, 226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 1 truck, 210.0ms
# Speed: 3.7ms preprocess, 210.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 227.7ms
# Speed: 8.5ms preprocess, 227.7ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 213.6ms
# Speed: 5.7ms preprocess, 213.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 1 bus, 245.1ms
# Speed: 3.4ms preprocess, 245.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 205.0ms
# Speed: 7.1ms preprocess, 205.0ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 1 truck, 210.6ms
# Speed: 8.5ms preprocess, 210.6ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 1 bus, 219.5ms
# Speed: 0.5ms preprocess, 219.5ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 210.0ms
# Speed: 6.0ms preprocess, 210.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 4 cars, 1 bus, 208.0ms
# Speed: 6.0ms preprocess, 208.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 207.6ms
# Speed: 0.0ms preprocess, 207.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 191.0ms
# Speed: 6.6ms preprocess, 191.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 194.8ms
# Speed: 9.8ms preprocess, 194.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 195.2ms
# Speed: 5.0ms preprocess, 195.2ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 205.0ms
# Speed: 9.0ms preprocess, 205.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 1 bus, 199.8ms
# Speed: 5.0ms preprocess, 199.8ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 6 cars, 199.7ms
# Speed: 9.9ms preprocess, 199.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 1 bus, 205.5ms
# Speed: 4.5ms preprocess, 205.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 1 bus, 207.5ms
# Speed: 8.7ms preprocess, 207.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 213.0ms
# Speed: 2.6ms preprocess, 213.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 188.1ms
# Speed: 6.9ms preprocess, 188.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 193.4ms
# Speed: 4.9ms preprocess, 193.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 212.5ms
# Speed: 0.0ms preprocess, 212.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 207.8ms
# Speed: 4.6ms preprocess, 207.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 209.8ms
# Speed: 5.0ms preprocess, 209.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 1 bus, 184.8ms
# Speed: 3.6ms preprocess, 184.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 168.1ms
# Speed: 5.2ms preprocess, 168.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 bus, 1 truck, 162.0ms
# Speed: 12.9ms preprocess, 162.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 1 truck, 185.3ms
# Speed: 5.1ms preprocess, 185.3ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 1 bus, 162.8ms
# Speed: 7.6ms preprocess, 162.8ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 170.0ms
# Speed: 3.5ms preprocess, 170.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 157.3ms
# Speed: 12.7ms preprocess, 157.3ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 162.3ms
# Speed: 9.3ms preprocess, 162.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 174.0ms
# Speed: 5.6ms preprocess, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 160.1ms
# Speed: 3.5ms preprocess, 160.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 162.1ms
# Speed: 9.9ms preprocess, 162.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 179.6ms
# Speed: 5.1ms preprocess, 179.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 169.0ms
# Speed: 7.1ms preprocess, 169.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 165.1ms
# Speed: 8.1ms preprocess, 165.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 177.2ms
# Speed: 6.0ms preprocess, 177.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 218.0ms
# Speed: 5.0ms preprocess, 218.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 156.9ms
# Speed: 7.5ms preprocess, 156.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 167.4ms
# Speed: 8.9ms preprocess, 167.4ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 171.6ms
# Speed: 12.8ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 3 cars, 173.9ms
# Speed: 7.3ms preprocess, 173.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 260.9ms
# Speed: 7.0ms preprocess, 260.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 179.1ms
# Speed: 5.4ms preprocess, 179.1ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 4 cars, 183.6ms
# Speed: 3.5ms preprocess, 183.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 169.4ms
# Speed: 6.0ms preprocess, 169.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 214.7ms
# Speed: 7.7ms preprocess, 214.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 220.3ms
# Speed: 5.0ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 213.9ms
# Speed: 2.0ms preprocess, 213.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 215.1ms
# Speed: 7.6ms preprocess, 215.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 227.2ms
# Speed: 0.9ms preprocess, 227.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 204.9ms
# Speed: 6.5ms preprocess, 204.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 214.6ms
# Speed: 11.0ms preprocess, 214.6ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 203.1ms
# Speed: 9.4ms preprocess, 203.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 188.8ms
# Speed: 10.2ms preprocess, 188.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 195.7ms
# Speed: 0.0ms preprocess, 195.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 232.4ms
# Speed: 0.0ms preprocess, 232.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 225.9ms
# Speed: 3.0ms preprocess, 225.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 214.1ms
# Speed: 11.5ms preprocess, 214.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 197.7ms
# Speed: 7.0ms preprocess, 197.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 220.2ms
# Speed: 5.6ms preprocess, 220.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 229.3ms
# Speed: 5.0ms preprocess, 229.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 192.7ms
# Speed: 24.9ms preprocess, 192.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 146.8ms
# Speed: 4.6ms preprocess, 146.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 123.7ms
# Speed: 6.0ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 195.5ms
# Speed: 5.0ms preprocess, 195.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 249.7ms
# Speed: 4.0ms preprocess, 249.7ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 244.2ms
# Speed: 13.8ms preprocess, 244.2ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 212.4ms
# Speed: 12.4ms preprocess, 212.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 275.7ms
# Speed: 9.7ms preprocess, 275.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 282.1ms
# Speed: 2.5ms preprocess, 282.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 200.0ms
# Speed: 5.1ms preprocess, 200.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 221.9ms
# Speed: 11.5ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 266.7ms
# Speed: 8.0ms preprocess, 266.7ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 198.7ms
# Speed: 14.2ms preprocess, 198.7ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 206.5ms
# Speed: 15.3ms preprocess, 206.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 267.8ms
# Speed: 7.1ms preprocess, 267.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 231.6ms
# Speed: 8.2ms preprocess, 231.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 220.6ms
# Speed: 19.3ms preprocess, 220.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 209.9ms
# Speed: 7.2ms preprocess, 209.9ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 256.9ms
# Speed: 9.6ms preprocess, 256.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 230.1ms
# Speed: 5.8ms preprocess, 230.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 211.3ms
# Speed: 4.8ms preprocess, 211.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 200.6ms
# Speed: 8.2ms preprocess, 200.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 239.1ms
# Speed: 6.3ms preprocess, 239.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 335.0ms
# Speed: 4.8ms preprocess, 335.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 219.4ms
# Speed: 13.4ms preprocess, 219.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 228.1ms
# Speed: 12.2ms preprocess, 228.1ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 239.7ms
# Speed: 8.5ms preprocess, 239.7ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 349.4ms
# Speed: 40.6ms preprocess, 349.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 213.3ms
# Speed: 15.7ms preprocess, 213.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 193.6ms
# Speed: 4.5ms preprocess, 193.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 210.5ms
# Speed: 8.6ms preprocess, 210.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 212.0ms
# Speed: 8.1ms preprocess, 212.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 205.1ms
# Speed: 4.5ms preprocess, 205.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 197.5ms
# Speed: 9.6ms preprocess, 197.5ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 204.9ms
# Speed: 5.0ms preprocess, 204.9ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 197.4ms
# Speed: 8.2ms preprocess, 197.4ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 206.8ms
# Speed: 7.1ms preprocess, 206.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 221.8ms
# Speed: 19.3ms preprocess, 221.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 215.7ms
# Speed: 4.1ms preprocess, 215.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 184.9ms
# Speed: 9.7ms preprocess, 184.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 177.6ms
# Speed: 4.0ms preprocess, 177.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 185.0ms
# Speed: 8.0ms preprocess, 185.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 224.7ms
# Speed: 4.0ms preprocess, 224.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 170.6ms
# Speed: 6.3ms preprocess, 170.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 168.8ms
# Speed: 14.0ms preprocess, 168.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 1 traffic light, 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 199.7ms
# Speed: 8.8ms preprocess, 199.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 1 traffic light, 176.4ms
# Speed: 0.0ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
